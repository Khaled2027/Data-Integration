# %%
# %sql
CREATE CATALOG IF NOT EXISTS Data_Integration;
CREATE SCHEMA IF NOT EXISTS Data_Integration.Project;
CREATE VOLUME IF NOT EXISTS Data_Integration.Project.datasets;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# Austin
airbnb_austin_reviews_df= spark.read.format("csv").option("header","true").option("inferSchema","true").load("/Volumes/data_integration/project/datasets/Data/Airbnb_Austin_Reviews.csv")
# Berlin
airbnb_berlin_reviews_df=spark.read.format("csv").option("header","true").option("inferSchema","true").load("/Volumes/data_integration/project/datasets/Data/Airbnb_Berlin_Reviews.csv")
# Barcelona
airbnb_barcelona_reviews_df=spark.read.format("csv").option("header","true").option("inferSchema","true").load("/Volumes/data_integration/project/datasets/Data/Airbnb_Barcelona_Reviews.csv")
#Bangkok
airbnb_bangkok_reviews_df=spark.read.format("csv").option("header","true").option("inferSchema","true").load("/Volumes/data_integration/project/datasets/Data/Airbnb_Bangkok_Reviews.csv")

reviews_df_list=[airbnb_austin_reviews_df,airbnb_berlin_reviews_df, airbnb_barcelona_reviews_df,airbnb_bangkok_reviews_df]
def show_sc(df):
    for i in df:
        i.printSchema()
        
show_sc(reviews_df_list)
# Out:
# root
#  |-- listing_id: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- reviewer_id: string (nullable = true)
#  |-- reviewer_name: string (nullable = true)
#  |-- comments: string (nullable = true)
#
# root
#  |-- listing_id: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- reviewer_id: string (nullable = true)
#  |-- reviewer_name: string (nullable = true)
#  |-- comments: string (nullable = true)
#
# root
#  |-- listing_id: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- reviewer_id: string (nullable = true)
#  |-- reviewer_name: string (nullable = true)
#  |-- comments: string (nullable = true)
#
# root
#  |-- listing_id: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- reviewer_id: string (nullable = true)
#  |-- reviewer_name: string (nullable = true)
# ...
